# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Order.csv

# %%
#Importing Order csv
df = pd.read_csv(r'C:\Users\16175\Desktop\Instacart Project\02 Data\Original data\orders.csv', index_col = False)

# %%
#creating a shortcut
path = r'C:\Users\16175\Desktop\Instacart Project'

# %%
#Shortcut
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %% [markdown]
# # Product.csv

# %%
df2 = pd.read_csv(r'C:\Users\16175\Desktop\Instacart Project\02 Data\Original data\products.csv', index_col = False)

# %%
df2 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
df2
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
#dropping eval_set column from order table
df.drop(columns = {'eval_set'})
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
#rename column
df.rename(columns = {'order_dow' : 'order_days_of_the_week'}, inplace = True)

# %%
#order_number does not need to be included as a numeric value
df['order_number'] = df['order_number'].astype('str')

# %%
#changing to a more precise name
df.rename(columns = {'days_since_prior_order' : 'days_since_last_order'}, inplace = True)

# %%
#calculating the busiest hour of the day
df['order_hour_of_day'].mode(dropna = False)
# Out:
# 0    10
# dtype: int64

# %% [markdown]
# # Department.csv

# %%
df3 = pd.read_csv(r'C:\Users\16175\Desktop\Instacart Project\02 Data\Original data\departments.csv', index_col = False)

# %%
df3
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
df3.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df3_t = df3.T

# %%
df3_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df3_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
#creating a new header
new_header = df3_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
#replacing the old header with the new
df3_t_new = df3_t[1:]

# %%
df3_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
df3_t_new.columns = new_header

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
df3_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#value of department_id 5 of dfproduce
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
df_breakfast = df2[df2['department_id']==14]

# %% [markdown]
# # Data Dictionary

# %%
df2.columns
# Out:
# Index(['product_id', 'product_name', 'aisle_id', 'department_id', 'prices'], dtype='object')

# %%
data_dict = df3_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df2.head(5)
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_breakfast
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %% [markdown]
# # We Like to Party

# %%
#customers who might throw a dinner party
df_dinner_parties = df2[df2['department_id'].isin([14, 20, 7, 12])]

# %%
df_dinner_parties
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49674       49670                             Beef Summer Sausage       106
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
#
#        department_id  prices
# ...

# %%
#Answer
#Number of Rows=7710, Columns=5 for Dinner Parties

# %% [markdown]
# # Customer Analysis

# %%
#User_id '1' Analysis
df['user_id']==1
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 3421078    False
# 3421079    False
# 3421080    False
# 3421081    False
# 3421082    False
# Name: user_id, Length: 3421083, dtype: bool

# %%
#User_id 1 information
df_customer = df[df['user_id'].isin([1])]

# %%
df_customer
# Out:
#     order_id  user_id eval_set order_number  order_days_of_the_week  \
# 0    2539329        1    prior            1                       2
# 1    2398795        1    prior            2                       3
# 2     473747        1    prior            3                       3
# 3    2254736        1    prior            4                       4
# 4     431534        1    prior            5                       4
# 5    3367565        1    prior            6                       2
# 6     550135        1    prior            7                       1
# 7    3108588        1    prior            8                       1
# 8    2295261        1    prior            9                       1
# 9    2550362        1    prior           10                       4
# 10   1187899        1    train           11                       4
#
#     order_hour_of_day  days_since_last_order
# 0                   8                    NaN
# 1                   7                   15.0
# ...

# %%
#User_id 1 Analysis
This customer has a pattern of ordering between day 1- Assuming Monday as the first day of the week and day 4. 
There is also a pattern with the time, orders are placed no earlier than 7am and no later than 1600hrs. 
We can assume that this customer prefers stocking up for the weekend to avoid going out or perhaps weekdays have discount rates compared to weekend rates.
# Out:
#   File "<ipython-input-65-eacab5e2f89d>", line 3
#     This customer has a pattern of ordering between day 1- Assuming Monday as the first day of the week and day 4.
#          ^
# SyntaxError: invalid syntax

# %%
df.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %%
df3_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'department_wrangled.csv'))
